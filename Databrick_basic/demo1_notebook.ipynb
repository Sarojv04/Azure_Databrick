# %%
print("this is python cell")

# %%
# %sql
SELECT 2 + 3 AS result;

# %%
# To see all default datasets listed under databricks-datasets.
# %fs ls 'databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
file_info = dbutils.fs.ls('databricks-datasets')
display(file_info)
