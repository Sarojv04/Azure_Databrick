# %%
# %sql
select current_catalog();

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS mydb;

# %%
# %sql
select * from databrickproject.mydb.electronics_products;

# %%
# %sql
-- Filter by category

select * from databrickproject.mydb.electronics_products where colour = 'Pink';

# %%
# %sql
select * from databrickproject.mydb.electronics_products where price >= 400
order by price;

# %%
# %sql
select productName, colour from databrickproject.mydb.electronics_products
group by productName,colour;

# %%
# %sql

select colour, COUNT(*) as total_products
from databrickproject.mydb.electronics_products
group by colour;
